# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ### Introduction
#
# #### Why controlled experiments?
#
# Why not measure the metric(s) you're interested before and after making a change and measure the delta? The outside world has a larger effect of metrics than product changes.
#
# #### Promoting a culture of experimentation
#
#
# #### The Ideas Funnel
#
# How can a company generate ideas for experimentation?
#
# - Bhavik Framework

# %%
Image(filename='../images/sundial_experimentation.jpg', width=500, height=500)

# %% [markdown]
# - AARRR Metrics
#
# Another potential source of test ideas is to consider your funnel and the associated pirate metrics:
#     - Acquisition
#     - Activation
#     - Retention
#     - Referral
#     - Revenue
#
# https://medium.com/@ms.mbalke/aarrr-framework-metrics-that-let-your-startup-sound-like-a-pirate-ship-e91d4082994b
#
# http://startitup.co/guides/374/aarrr-startup-metrics
#
# - Kohavi Comments
#
# Cannot test every single idea despite online experiments being the most high fidelity option. Focus groups and mockups are lower fidelity but are quicker and cheaper to run - use this to whittle down your ideas to the select few that you focus on and test.
#
# - Prioritising Hypotheses
#     - Potential revenue impact
#     - Customer benefit
#     - Level of effort

# %% [markdown]
# ### References
#
# - d
